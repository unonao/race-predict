# %%
import numpy as np
import pandas as pd
#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)

# %%
race_df = pd.read_csv("./csv/cleaned_race_data.csv", sep=",")

# %%
horse_df = pd.read_csv("./csv/cleaned_horse_data.csv", sep=",")
# Out:
# /Users/murakaminaoki/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# race
print(race_df.dtypes)
race_df.head(3)
# Out:
# race_id                        int64
# race_round                     int64
# ground_status                  int64
# date                          object
# total_horse_number             int64
# frame_number_first             int64
# horse_number_first             int64
# frame_number_second            int64
# horse_number_second            int64
# frame_number_third             int64
# horse_number_third             int64
# tansyo                         int64
# hukuren_first                  int64
# hukuren_second                 int64
# hukuren_third                  int64
# renhuku3                       int64
# rentan3                        int64
# is_obstacle                  float64
# distance                       int64
# weather_rain                   int64
# weather_snow                   int64
# weather_小雨                     int64
# weather_小雪                     int64
# weather_晴                      int64
# weather_曇                      int64
# ...

# %%
# horse
print(horse_df.dtypes)
horse_df.head(3)
# Out:
# race_id                 int64
# rank                    int64
# frame_number            int64
# horse_number            int64
# horse_id                int64
# age                     int64
# burden_weight         float64
# rider_id                int64
# goal_time             float64
# half_way_rank         float64
# last_time             float64
# odds                  float64
# popular               float64
# horse_weight          float64
# tamer_id                int64
# owner_id               object
# date                   object
# is_down                 int64
# is_senba                int64
# is_mesu                 int64
# is_osu                  int64
# distance                int64
# avg_velocity          float64
# horse_weight_dif      float64
# burden_weight_rate    float64
# dtype: object
#         race_id  rank  frame_number  horse_number    horse_id  age  \
# 0  200810010312     1             4             7  2004110053    4
# ...

# %% [markdown]
# raceからの追加
# - ground_status
# - weather_rain
# - weather_snow
# -
# ```Python
# race_df = pd.get_dummies(race_df, columns=["weather",'where_racecourse','ground_type','is_left_right_straight'])
# ```
#
#
#
# 追加項目
# - 前回のレース日時からの差
# - rider_idの変化があるか(あるなら1)
# -

# %%
one_horse_data = horse_df[horse_df['horse_id'] == 2004110053]

# %%
one_horse_data.sort_values('date').head(3)
# Out:
#            race_id  rank  frame_number  horse_number    horse_id  age  \
# 0     200810010312     1             4             7  2004110053    4
# 7450  200809010410     2             2             3  2004110053    4
# 9213  200807010911    14             7            13  2004110053    4
#
#       burden_weight  rider_id  goal_time  half_way_rank  last_time  odds  \
# 0              56.0       674       69.7           11.5       35.9   9.7
# 7450           57.0       674       81.9            4.0       35.5   3.4
# 9213           57.0       674       69.3           11.0       35.3   5.1
#
#       popular  horse_weight  tamer_id owner_id                 date  is_down  \
# 0         4.0         484.0      1075    19004  2008-01-26 16:05:00        0
# 7450      1.0         486.0      1075    19004  2008-03-09 15:10:00        0
# 9213      2.0         486.0      1075    19004  2008-03-29 15:30:00        0
#
#       is_senba  is_mesu  is_osu  distance  avg_velocity  horse_weight_dif  \
# ...

# %%
def make_one_horse_train_data(one_horse_data):
# Out:
#   File "<ipython-input-21-546f351f0fcd>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing
